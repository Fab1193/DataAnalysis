# %% [markdown]
# **Data from Kaggle published by Apple on Jan 2nd (https://www.kaggle.com/prasertk/apple-product-price-list-from-26-countries-2022). Data cleaning by Fabricio Quesada.**

# %%
import re
import osmnx as ox
import numpy as np
import pandas as pd
import requests
from forex_python.converter import CurrencyRates
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Cleaning

# %%
apple = pd.read_csv('apple product price list from 26 countries.csv')

# %% [markdown]
# **Number of countries in the file**

# %%
len(apple.country.unique())
# Out:
# 26

# %%
apple.shape
# Out:
# (448, 8)

# %% [markdown]
# **Check data head and tail**

# %%
apple.head(10)
# Out:
#    pid                    model         price country_code    country  \
# 0    0                iPhone 13  From A$1,199           au  Australia
# 1    1                iPhone SE    From A$679           au  Australia
# 2    2                iPhone 12    From A$999           au  Australia
# 3    3  AirPods(3rd generation)         A$279           au  Australia
# 4    4              AirPods Pro         A$399           au  Australia
# 5    5  AirPods(2nd generation)         A$219           au  Australia
# 6    6              AirPods Max         A$899           au  Australia
# 7    7              Apple TV 4K         A$249           au  Australia
# 8    8           Apple Watch SE    From A$429           au  Australia
# 9    9     Apple Watch Series 3    From A$299           au  Australia
#
#                 region income group                scraped_date
# 0  East Asia & Pacific  High income  2022-01-02 21:52:06.630535
# 1  East Asia & Pacific  High income  2022-01-02 21:52:06.630535
# 2  East Asia & Pacific  High income  2022-01-02 21:52:06.630535
# 3  East Asia & Pacific  High income  2022-01-02 21:52:06.630535
# 4  East Asia & Pacific  High income  2022-01-02 21:52:06.630535
# 5  East Asia & Pacific  High income  2022-01-02 21:52:06.630535
# 6  East Asia & Pacific  High income  2022-01-02 21:52:06.630535
# 7  East Asia & Pacific  High income  2022-01-02 21:52:06.630535
# 8  East Asia & Pacific  High income  2022-01-02 21:52:06.630535
# 9  East Asia & Pacific  High income  2022-01-02 21:52:06.630535

# %%
apple.tail(10)
# Out:
#      pid                          model  \
# 438    7                    Apple TV 4K
# 439    8                 Apple Watch SE
# 440    9           Apple Watch Series 3
# 441   10                     Sport Band
# 442   11                           iPad
# 443   12                       iPad Pro
# 444   13  Apple Pencil (2nd generation)
# 445   14                  24-inch iMac²
# 446   15                    MacBook Air
# 447   16                    Magic Mouse
#
#                                                price country_code  \
# 438  From $179.00 or $29.83/mo. per month for 6 mo.*           us
# 439    From $279 or $11.62/mo. per month for 24 mo.*           us
# 440     From $199 or $8.29/mo. per month for 24 mo.*           us
# 441           $49 or $4.08/mo. per month for 12 mo.*           us
# 442    From $329 or $27.41/mo. per month for 12 mo.*           us
# 443    From $799 or $66.58/mo. per month for 12 mo.*           us
# 444         $129 or $10.75/mo. per month for 12 mo.*           us
# 445  From $1299 or $108.25/mo. per month for 12 mo.*           us
# 446    From $999 or $83.25/mo. per month for 12 mo.*           us
# 447                                              $79           us
#
#            country         region income group                scraped_date
# 438  United States  North America  High income  2022-01-02 21:52:47.021744
# 439  United States  North America  High income  2022-01-02 21:52:47.021744
# 440  United States  North America  High income  2022-01-02 21:52:47.021744
# 441  United States  North America  High income  2022-01-02 21:52:47.021744
# 442  United States  North America  High income  2022-01-02 21:52:47.021744
# 443  United States  North America  High income  2022-01-02 21:52:47.021744
# 444  United States  North America  High income  2022-01-02 21:52:47.021744
# 445  United States  North America  High income  2022-01-02 21:52:47.021744
# 446  United States  North America  High income  2022-01-02 21:52:47.021744
# 447  United States  North America  High income  2022-01-02 21:52:47.021744

# %% [markdown]
# **Spaces replaced in the price column**

# %%
price_list = []
for i in apple.price:
    i = i.replace(' ', '')
    price_list.append(i)
apple['price_local_currency'] = np.array(price_list)

# %% [markdown]
# **Find all numbers in the price column. For all products the price is always the first number, the for loop down below gets that first number**

# %%
p = '[\d]+[.,\d]+|[\d]*[.][\d]+|[\d]+'
d = [np.nan]*len(apple.price_local_currency)
for i in range(0, len(apple.price_local_currency)):
    e = []
    s = apple.price_local_currency[i]
    if re.search(p, s) is not None:
        for catch in re.finditer(p, s):
            e.append(catch[0])
        d[i] = e[0]
apple['price_local_currency'] = d

# %%
apple.head(10)
# Out:
#    pid                    model         price country_code    country  \
# 0    0                iPhone 13  From A$1,199           au  Australia
# 1    1                iPhone SE    From A$679           au  Australia
# 2    2                iPhone 12    From A$999           au  Australia
# 3    3  AirPods(3rd generation)         A$279           au  Australia
# 4    4              AirPods Pro         A$399           au  Australia
# 5    5  AirPods(2nd generation)         A$219           au  Australia
# 6    6              AirPods Max         A$899           au  Australia
# 7    7              Apple TV 4K         A$249           au  Australia
# 8    8           Apple Watch SE    From A$429           au  Australia
# 9    9     Apple Watch Series 3    From A$299           au  Australia
#
#                 region income group                scraped_date  \
# 0  East Asia & Pacific  High income  2022-01-02 21:52:06.630535
# 1  East Asia & Pacific  High income  2022-01-02 21:52:06.630535
# 2  East Asia & Pacific  High income  2022-01-02 21:52:06.630535
# 3  East Asia & Pacific  High income  2022-01-02 21:52:06.630535
# 4  East Asia & Pacific  High income  2022-01-02 21:52:06.630535
# 5  East Asia & Pacific  High income  2022-01-02 21:52:06.630535
# 6  East Asia & Pacific  High income  2022-01-02 21:52:06.630535
# 7  East Asia & Pacific  High income  2022-01-02 21:52:06.630535
# 8  East Asia & Pacific  High income  2022-01-02 21:52:06.630535
# 9  East Asia & Pacific  High income  2022-01-02 21:52:06.630535
#
#   price_local_currency
# 0                1,199
# 1                  679
# 2                  999
# 3                  279
# 4                  399
# 5                  219
# 6                  899
# 7                  249
# 8                  429
# 9                  299

# %%
apple.tail(10)
# Out:
#      pid                          model  \
# 438    7                    Apple TV 4K
# 439    8                 Apple Watch SE
# 440    9           Apple Watch Series 3
# 441   10                     Sport Band
# 442   11                           iPad
# 443   12                       iPad Pro
# 444   13  Apple Pencil (2nd generation)
# 445   14                  24-inch iMac²
# 446   15                    MacBook Air
# 447   16                    Magic Mouse
#
#                                                price country_code  \
# 438  From $179.00 or $29.83/mo. per month for 6 mo.*           us
# 439    From $279 or $11.62/mo. per month for 24 mo.*           us
# 440     From $199 or $8.29/mo. per month for 24 mo.*           us
# 441           $49 or $4.08/mo. per month for 12 mo.*           us
# 442    From $329 or $27.41/mo. per month for 12 mo.*           us
# 443    From $799 or $66.58/mo. per month for 12 mo.*           us
# 444         $129 or $10.75/mo. per month for 12 mo.*           us
# 445  From $1299 or $108.25/mo. per month for 12 mo.*           us
# 446    From $999 or $83.25/mo. per month for 12 mo.*           us
# 447                                              $79           us
#
#            country         region income group                scraped_date  \
# 438  United States  North America  High income  2022-01-02 21:52:47.021744
# 439  United States  North America  High income  2022-01-02 21:52:47.021744
# 440  United States  North America  High income  2022-01-02 21:52:47.021744
# 441  United States  North America  High income  2022-01-02 21:52:47.021744
# 442  United States  North America  High income  2022-01-02 21:52:47.021744
# 443  United States  North America  High income  2022-01-02 21:52:47.021744
# 444  United States  North America  High income  2022-01-02 21:52:47.021744
# 445  United States  North America  High income  2022-01-02 21:52:47.021744
# 446  United States  North America  High income  2022-01-02 21:52:47.021744
# 447  United States  North America  High income  2022-01-02 21:52:47.021744
#
#     price_local_currency
# 438               179.00
# 439                  279
# 440                  199
# 441                   49
# 442                  329
# 443                  799
# 444                  129
# 445                 1299
# 446                  999
# 447                   79

# %% [markdown]
# **This function will help in the two dataframes merging process**

# %%
def special_characters (text):
        text = re.sub('á','a', text)
        text = re.sub('é','e', text)
        text = re.sub('í','i', text)
        text = re.sub('ó','o', text)
        text = re.sub('ú','u', text)
        text = re.sub('ñ','n', text)
        text = re.sub('Á','a', text)
        text = re.sub('É','e', text)
        text = re.sub('Í','i', text)
        text = re.sub('Ó','o', text)
        text = re.sub('Ú','u', text)
        text = re.sub('Ñ','N', text)
        return text.upper()

# %% [markdown]
# **The prices are in local currencies, they will need to be in USD.**

# %%
url = 'https://www.iban.com/currency-codes'
html = requests.get(url).content
df_list = pd.read_html(html)
currencies = df_list[-1]
currencies
# Out:
#                Country         Currency Code  Number
# 0          AFGHANISTAN          Afghani  AFN   971.0
# 1        ÅLAND ISLANDS             Euro  EUR   978.0
# 2              ALBANIA              Lek  ALL     8.0
# 3              ALGERIA   Algerian Dinar  DZD    12.0
# 4       AMERICAN SAMOA        US Dollar  USD   840.0
# ..                 ...              ...  ...     ...
# 263  WALLIS AND FUTUNA        CFP Franc  XPF   953.0
# 264     WESTERN SAHARA  Moroccan Dirham  MAD   504.0
# 265              YEMEN      Yemeni Rial  YER   886.0
# 266             ZAMBIA   Zambian Kwacha  ZMW   967.0
# 267           ZIMBABWE  Zimbabwe Dollar  ZWL   932.0
#
# [268 rows x 4 columns]

# %% [markdown]
# **To match countries between the apple table and the currency_code table I need to remove the data between parenthesis and change some countries names, for instance, 'NETHERLANDS (THE)' to 'NETHERLANDS' and 'UNITED STATES OF AMERICA' to 'UNITED STATES'**

# %%
for i in range(0,len(currencies['Country'])):
    currencies.Country[i] = re.sub("\(.*?\)","()",currencies.Country[i])
    currencies.Country[i] = currencies.Country[i].replace(' ()', '')
    currencies.Country[i] = currencies.Country[i].replace('UNITED STATES OF AMERICA', 'UNITED STATES')
    currencies.Country[i] = currencies.Country[i].replace('RUSSIAN FEDERATION', 'RUSSIA')

# %%
currencies.shape
# Out:
# (268, 4)

# %% [markdown]
# **USN and MXV appear as currencies for Mexico and United States but those won't be used. I delete them from the dataframe to avoid duplicates when merging apple table and currencies table**

# %%
currencies = currencies.loc[(currencies["Code"] != 'USN') & (currencies["Code"] != 'MXV')]

# %%
currencies.shape
# Out:
# (266, 4)

# %% [markdown]
# **Replace some additional special characters**

# %%
currencies.Country = [special_characters(x) for x in currencies.Country]
apple.country = [special_characters(x) for x in apple.country]

# %% [markdown]
# **Currencies table and apple table merge**

# %%
apple = apple.merge(currencies, left_on = "country", right_on = 'Country')
apple = apple.drop(['scraped_date', 'price', 'Country','Number'], axis = 1)
apple.rename(columns = {'income group': 'income_group'}, inplace=True)

# %%
apple.head()
# Out:
#    pid                    model country_code    country               region  \
# 0    0                iPhone 13           au  AUSTRALIA  East Asia & Pacific
# 1    1                iPhone SE           au  AUSTRALIA  East Asia & Pacific
# 2    2                iPhone 12           au  AUSTRALIA  East Asia & Pacific
# 3    3  AirPods(3rd generation)           au  AUSTRALIA  East Asia & Pacific
# 4    4              AirPods Pro           au  AUSTRALIA  East Asia & Pacific
#
#   income_group price_local_currency           Currency Code
# 0  High income                1,199  Australian Dollar  AUD
# 1  High income                  679  Australian Dollar  AUD
# 2  High income                  999  Australian Dollar  AUD
# 3  High income                  279  Australian Dollar  AUD
# 4  High income                  399  Australian Dollar  AUD

# %% [markdown]
# **The number of countries is the same as when I imported the data, there are not missing countries**

# %%
len(apple.country.unique())
# Out:
# 26

# %% [markdown]
# **List of countries that use comma for decimals (https://www.dfa.cornell.edu/treasurer/cash-management/processinginternational/intl-currency)**

# %%
comma_countries = ['Albania',
'Algeria',
'Andorra',
'Angola',
'Argentina',
'Armenia',
'Austria',
'Azerbaijan',
'Belarus',
'Belgium',
'Bolivia',
'Bosnia and Herzegovina',
'Brazil',
'Bulgaria',
'Cameroon',
'Chile',
'Colombia',
'Costa Rica',
'Croatia',
'Cuba',
'Cyprus',
'Czechia',
'Denmark',
'East Timor',
'Ecuador',
'Estonia',
'Faroes',
'Finland',
'France',
'Germany',
'Georgia',
'Greece',
'Greenland',
'Hungary',
'Iceland',
'Indonesia',
'Italy',
'Kazakhstan',
'Kosovo',
'Kyrgyzstan',
'Latvia',
'Lebanon',
'Lithuania',
'Luxembourg',
'Macau',
'Mauritania',
'Moldova',
'Mongolia',
'Morocco',
'Mozambique',
'Namibia',
'Netherlands',
'North Macedonia',
'Norway',
'Paraguay',
'Peru',
'Poland',
'Portugal',
'Romania',
'Russia',
'Serbia',
'Slovakia',
'Slovenia',
'Somalia',
'South Africa',
'Spain',
'Suriname',
'Sweden',
'Switzerland',
'Tunisia',
'Turkey',
'Turkmenistan',
'Ukraine',
'Uruguay',
'Uzbekistan',
'Venezuela',
'Vietnam',
'Zimbabwe']

# %% [markdown]
# **Uppercase to all the countries in the list**

# %%
comma_countries = [x.upper() for x in comma_countries]
comma_countries
# Out:
# ['ALBANIA',
#  'ALGERIA',
#  'ANDORRA',
#  'ANGOLA',
#  'ARGENTINA',
#  'ARMENIA',
#  'AUSTRIA',
#  'AZERBAIJAN',
#  'BELARUS',
#  'BELGIUM',
#  'BOLIVIA',
#  'BOSNIA AND HERZEGOVINA',
#  'BRAZIL',
#  'BULGARIA',
#  'CAMEROON',
#  'CHILE',
#  'COLOMBIA',
#  'COSTA RICA',
#  'CROATIA',
#  'CUBA',
#  'CYPRUS',
#  'CZECHIA',
#  'DENMARK',
#  'EAST TIMOR',
#  'ECUADOR',
#  'ESTONIA',
#  'FAROES',
#  'FINLAND',
#  'FRANCE',
#  'GERMANY',
#  'GEORGIA',
#  'GREECE',
#  'GREENLAND',
#  'HUNGARY',
#  'ICELAND',
#  'INDONESIA',
#  'ITALY',
#  'KAZAKHSTAN',
#  'KOSOVO',
#  'KYRGYZSTAN',
#  'LATVIA',
#  'LEBANON',
#  'LITHUANIA',
#  'LUXEMBOURG',
#  'MACAU',
#  'MAURITANIA',
#  'MOLDOVA',
#  'MONGOLIA',
#  'MOROCCO',
#  'MOZAMBIQUE',
#  'NAMIBIA',
#  'NETHERLANDS',
#  'NORTH MACEDONIA',
#  'NORWAY',
#  'PARAGUAY',
#  'PERU',
#  'POLAND',
#  'PORTUGAL',
#  'ROMANIA',
#  'RUSSIA',
#  'SERBIA',
#  'SLOVAKIA',
#  'SLOVENIA',
#  'SOMALIA',
#  'SOUTH AFRICA',
#  'SPAIN',
#  'SURINAME',
#  'SWEDEN',
#  'SWITZERLAND',
#  'TUNISIA',
#  'TURKEY',
#  'TURKMENISTAN',
#  'UKRAINE',
#  'URUGUAY',
#  'UZBEKISTAN',
#  'VENEZUELA',
#  'VIETNAM',
#  'ZIMBABWE']

# %% [markdown]
# **Change all prices to the same format: dot for decimals**

# %%
for z in range(0, len(apple.country)):
    if apple.country[z] not in comma_countries:
        apple.price_local_currency[z] = str(apple.price_local_currency[z]).replace(',', '')
    else:
        apple.price_local_currency[z] = str(apple.price_local_currency[z]).replace('.', '')
        apple.price_local_currency[z] = str(apple.price_local_currency[z]).replace(',', '.')

# %% [markdown]
# **The shape remains the same**

# %%
apple.shape
# Out:
# (448, 9)

# %% [markdown]
# **Check for nan values**

# %%
apple[apple["price_local_currency"] == 'nan']
# Out:
#      pid                                        model country_code country  \
# 127    8               Tarjeta regalo del Apple Store           es   SPAIN
# 231    8                     Carta regalo Apple Store           it   ITALY
# 266    8                  Tarjetas App Store & iTunes           mx  MEXICO
# 369    8                      Подарочные карты iTunes           ru  RUSSIA
# 421    8  App Store ve iTunes Hediye Kartı satın alın           tr  TURKEY
#
#                         region         income_group price_local_currency  \
# 127      Europe & Central Asia          High income                  nan
# 231      Europe & Central Asia          High income                  nan
# 266  Latin America & Caribbean  Upper middle income                  nan
# 369      Europe & Central Asia  Upper middle income                  nan
# 421      Europe & Central Asia  Upper middle income                  nan
#
#           Currency Code
# 127           Euro  EUR
# 231           Euro  EUR
# 266   Mexican Peso  MXN
# 369  Russian Ruble  RUB
# 421   Turkish Lira  TRY

# %% [markdown]
# **Drop nan values**

# %%
apple = apple.loc[(apple["price_local_currency"] != 'nan')]

# %% [markdown]
# **Change column to numeric**

# %%
apple[["price_local_currency"]] = apple[["price_local_currency"]] .apply(pd.to_numeric)

# %% [markdown]
# **Prices in USD (Currency Exchange)**

# %%
dicte = {}
cur = apple.Code.unique()
c = CurrencyRates()
for l in range(0, len(cur)):
     dicte.update({cur[l] : c.convert( cur[l], 'USD', 1)})

# %%
rates = pd.DataFrame(
    {'codes': dicte.keys(), 'rate': dicte.values()})
rates
# Out:
#    codes      rate
# 0    AUD  0.723663
# 1    EUR  1.135500
# 2    BRL  0.178709
# 3    CAD  0.787448
# 4    CZK  0.045753
# 5    DKK  0.152658
# 6    HUF  0.003088
# 7    INR  0.013455
# 8    MXN  0.048889
# 9    NOK  0.113535
# 10   PHP  0.019560
# 11   PLN  0.247413
# 12   RUB  0.013433
# 13   SEK  0.110288
# 14   THB  0.030147
# 15   TRY  0.075310
# 16   USD  1.000000

# %% [markdown]
# **Merge apple table with rates table**

# %%
apple = apple.merge(rates, left_on = "Code", right_on = 'codes')

# %% [markdown]
# **Get prices in USD**

# %%
try:
    apple['price_usd'] = apple['price_local_currency']*apple['rate']
except KeyError as e:
    raise ValueError('failed') from e

# %% [markdown]
# **Model column needs to be in english**

# %%
apple['model_en'] = ''

for m in range (0, len(apple.model)):
    if "iMac" in apple.model[m]:
        apple['model_en'][m] = '24-inch iMac²'
    else:
        apple['model_en'][m] = apple.model[m]
        
for n in range (0, len(apple.model)):
    if "AirPods(2" in apple.model[n]:
        apple['model_en'][n] = 'AirPods(2nd generation)'
    else:
        apple['model_en'][n] = apple.model_en[n]
        
for o in range (0, len(apple.model)):
    if "AirPods(3" in apple.model[o]:
        apple['model_en'][o] = 'AirPods(3rd generation)'
    else:
        apple['model_en'][o] = apple.model_en[o]
        
for p in range (0, len(apple.model)):
    if "Apple Pencil" in apple.model[p]:
        apple['model_en'][p] = 'Apple Pencil (2nd generation)'
    else:
        apple['model_en'][p] = apple.model_en[p]

# %%
apple.model_en.unique()
# Out:
# array(['iPhone 13', 'iPhone SE', 'iPhone 12', 'AirPods(3rd generation)',
#        'AirPods Pro', 'AirPods(2nd generation)', 'AirPods Max',
#        'Apple TV 4K', 'Apple Watch SE', 'Apple Watch Series 3',
#        'Sport Band', 'iPad', 'iPad Pro', 'Apple Pencil (2nd generation)',
#        '24-inch iMac²', 'MacBook Air', 'Magic Mouse', 'Apple TV HD',
#        'Sportarmband', 'iPhone 13 Pro', 'Correa deportiva',
#        'Urheiluranneke', 'Bracelet Sport', 'AirPods(terza generazione)',
#        'AirPods(seconda generazione)', 'Cinturino Sport', 'Sportbandje',
#        'Bracelete desportiva', 'Pulseira esportiva', 'Sportovní řemínek',
#        'Sportsrem', 'Sportszíj', 'AirPods(tercera generación)',
#        'AirPods(segunda generación)', 'Pasek sportowy',
#        'Спортивный ремешок', 'Мышь Magic Mouse',
#        'AirPods(tredje generationen)', 'AirPods(andra generationen)',
#        'Sportband', 'AirPods(รุ่นที่ 3)', 'AirPods(รุ่นที่ 2)',
#        'สายแบบ Sport Band', 'Spor Kordon'], dtype=object)

# %%
translate = {'AirPods(terza generazione)':'AirPods(3rd generation)',
             'AirPods(seconda generazione)':'AirPods(2nd generation)',
             'AirPods(tercera generación)':'AirPods(3rd generation)',
             'AirPods(segunda generación)':'AirPods(2nd generation)',
             'AirPods(tredje generationen)':'AirPods(3rd generation)',
             'AirPods(andra generationen)': 'AirPods(2nd generation)',
             'AirPods(รุ่นที่ 3)': 'AirPods(3rd generation)', 'AirPods(รุ่นที่ 2)':'AirPods(2nd generation)',
             'Мышь Magic Mouse':'Magic Mouse', 'Sportarmband':'Sport Band', 
             'Correa deportiva':'Sport Band', 'Urheiluranneke':'Sport Band',
             'Bracelet Sport':'Sport Band','Cinturino Sport':'Sport Band',
             'Sportbandje':'Sport Band','Bracelete desportiva':'Sport Band','Pulseira esportiva':'Sport Band',
             'Sportovní řemínek':'Sport Band','Sportsrem':'Sport Band','Sportszíj':'Sport Band',
             'Pasek sportowy':'Sport Band', 'Спортивный ремешок': 'Sport Band',
             'สายแบบ Sport Band':'Sport Band','Spor Kordon':'Sport Band'}

# %%
for q in range (0, len(apple.model_en)):
    for r in range(0,len(list(translate.keys()))):
        if list(translate.keys())[r] in apple.model_en[q]:
            apple['model_en'][q] = list(translate.values())[r]
        else:
            apple['model_en'][q] = apple.model_en[q]

# %% [markdown]
# **Some final formatting**

# %%
apple = apple[['pid', 'model_en', 'country', 'region', 'income_group', 'price_local_currency', 'Code', 'price_usd']]
apple.rename(columns = {'Code': 'code','model_en':'model'}, inplace=True)
apple['price_usd'] = round(apple['price_usd'],2)
for u in range(0, len(apple.country)):
    apple.country[u] = apple.country[u].title()
apple.head()
# Out:
#    pid                    model    country               region income_group  \
# 0    0                iPhone 13  Australia  East Asia & Pacific  High income
# 1    1                iPhone SE  Australia  East Asia & Pacific  High income
# 2    2                iPhone 12  Australia  East Asia & Pacific  High income
# 3    3  AirPods(3rd generation)  Australia  East Asia & Pacific  High income
# 4    4              AirPods Pro  Australia  East Asia & Pacific  High income
#
#    price_local_currency code  price_usd
# 0                1199.0  AUD     867.67
# 1                 679.0  AUD     491.37
# 2                 999.0  AUD     722.94
# 3                 279.0  AUD     201.90
# 4                 399.0  AUD     288.74

# %% [markdown]
# **Save new file**

# %%
apple.to_csv('apple.csv')
